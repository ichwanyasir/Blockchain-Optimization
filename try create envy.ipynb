# %%
from bs4 import BeautifulSoup

# %%
html_str = """
<!DOCTYPE html>
<html>
<head>
<meta charset="utf-8">
<title>Kost Tiong Paragon Exclusive Casablanca di daerah Jabodetabek - Jakarta Selatan - Setiabudi - Karet Kuningan - Infokost.id</title>
<meta name="keywords" content="Info Kost Tiong Paragon Exclusive Casablanca di daerah Jabodetabek - Jakarta Selatan - Setiabudi - Karet Kuningan, Sewa Kost Tiong Paragon Exclusive Casablanca di daerah Jabodetabek - Jakarta Selatan - Setiabudi - Karet Kuningan, infokost, kost, Jabodetabek - Jakarta Selatan - Setiabudi - Karet Kuningan infokost, ibukost, ibukos">
<meta name="description" content="Mau Sewa Kost Tiong Paragon Exclusive Casablanca di daerah Jabodetabek - Jakarta Selatan - Setiabudi - Karet Kuningan 
                Dapatkan Harga Termurah dengan Fasilitas berupa kamar mandi dalam, wifi, parkir dan lain lain Info Lengkap ada disini">
<link href="https://www.infokost.id/images/favicon.png" rel="shortcut icon" type="image/png">
<link rel="stylesheet" href="https://www.infokost.id/css/bootstrap.css" />
<link rel="stylesheet" href="https://www.infokost.id/css/magnific-popup.css" />
<link rel="stylesheet" href="https://www.infokost.id/css/flickity.css" />
<link rel="stylesheet" href="https://www.infokost.id/css/jquery.jscrollpane.css" />
<link rel="stylesheet" href="https://www.infokost.id/css/style.css" />
<link rel="stylesheet" href="https://www.infokost.id/css/jquery-ui/jquery-ui.css" />
<link href="https://fonts.googleapis.com/css?family=Roboto" rel="stylesheet">
<meta name="csrf-token" content="vSJCRKmSPxqfKJpBWy8Oi2hkooTcQjyyyNt0SRcU">
<script>window.Laravel = { csrfToken: 'vSJCRKmSPxqfKJpBWy8Oi2hkooTcQjyyyNt0SRcU', baseUrl: 'https://www.infokost.id' }</script>
<meta property="og:title" content="Kost Tiong Paragon Exclusive Casablanca di daerah Jabodetabek - Jakarta Selatan - Setiabudi - Karet Kuningan - Infokost.id">
<meta property="og:description" content="Mau Sewa Kost Tiong Paragon Exclusive Casablanca di daerah Jabodetabek - Jakarta Selatan - Setiabudi - Karet Kuningan 
                Dapatkan Harga Termurah dengan Fasilitas berupa kamar mandi dalam, wifi, parkir dan lain lain Info Lengkap ada disini">
<meta property="og:image" content="https://res.cloudinary.com/infokost/image/upload/w_660,h_420/v1510559129/prod/property/2017/11/13/kost-tiong-paragon-exclusive-casablanca-setiabudi-jakarta-selatan_1510559124_236.jpg">
<meta name="twitter:title" content="Kost Tiong Paragon Exclusive Casablanca di daerah Jabodetabek - Jakarta Selatan - Setiabudi - Karet Kuningan - Infokost.id">
<meta name="twitter:description" content=" Mau Sewa Kost Tiong Paragon Exclusive Casablanca di daerah Jabodetabek - Jakarta Selatan - Setiabudi - Karet Kuningan 
                Dapatkan Harga Termurah dengan Fasilitas berupa kamar mandi dalam, wifi, parkir dan lain lain Info Lengkap ada disini">
<meta name="twitter:image" content="https://res.cloudinary.com/infokost/image/upload/w_660,h_420/v1510559129/prod/property/2017/11/13/kost-tiong-paragon-exclusive-casablanca-setiabudi-jakarta-selatan_1510559124_236.jpg">
<meta name="twitter:card" content="summary_large_image">

<script>(function(w,d,s,l,i){w[l]=w[l]||[];w[l].push({'gtm.start':
                    new Date().getTime(),event:'gtm.js'});var f=d.getElementsByTagName(s)[0],
                j=d.createElement(s),dl=l!='dataLayer'?'&l='+l:'';j.async=true;j.src=
                'https://www.googletagmanager.com/gtm.js?id='+i+dl;f.parentNode.insertBefore(j,f);
            })(window,document,'script','dataLayer','GTM-55BRPMX');</script>


<script id="ze-snippet" src="https://static.zdassets.com/ekr/snippet.js?key=5686725e-e511-4ec7-a4a3-7c2e560df146"> </script>

<script type="application/ld+json">
        {
            "@context": "https://schema.org",
            "@type": "BreadcrumbList",
            "itemListElement": [
                                    {
                        "@type": "ListItem",
                        "position": 1,
                        "name": "detail",
                        "item": "https://www.infokost.id/detail"
                    }  ,                                     {
                        "@type": "ListItem",
                        "position": 2,
                        "name": "kost-tiong-paragon-exclusive-casablanca-setiabudi-jakarta-selatan",
                        "item": "https://www.infokost.id/detail/kost-tiong-paragon-exclusive-casablanca-setiabudi-jakarta-selatan"
                    }                             ]
        }
    </script>
<script type="application/ld+json">
        {
            "@context": "https://schema.org/",
            "@type": "Product",
            "name": "Kost Tiong Paragon Exclusive Casablanca",
            "description": "Mau Sewa Kost Tiong Paragon Exclusive Casablanca di daerah Jabodetabek - Jakarta Selatan - Setiabudi - Karet Kuningan 
                Dapatkan Harga Termurah dengan Fasilitas berupa kamar mandi dalam, wifi, parkir dan lain lain Info Lengkap ada disini",
            "image": [
                                                            "https://res.cloudinary.com/infokost/image/upload/w_660,h_420/v1510559129/prod/property/2017/11/13/kost-tiong-paragon-exclusive-casablanca-setiabudi-jakarta-selatan_1510559124_236.jpg",
                                                                                "https://res.cloudinary.com/infokost/image/upload/w_660,h_420/v1510559135/prod/property/2017/11/13/kost-tiong-paragon-exclusive-casablanca-setiabudi-jakarta-selatan_1510559130_803.jpg",
                                                                                "https://res.cloudinary.com/infokost/image/upload/w_660,h_420/v1510559141/prod/property/2017/11/13/kost-tiong-paragon-exclusive-casablanca-setiabudi-jakarta-selatan_1510559136_516.jpg",
                                                                                "https://res.cloudinary.com/infokost/image/upload/w_660,h_420/v1510559147/prod/property/2017/11/13/kost-tiong-paragon-exclusive-casablanca-setiabudi-jakarta-selatan_1510559142_735.jpg",
                                                                                "https://res.cloudinary.com/infokost/image/upload/w_660,h_420/v1510559153/prod/property/2017/11/13/kost-tiong-paragon-exclusive-casablanca-setiabudi-jakarta-selatan_1510559148_996.jpg",
                                                                                "https://res.cloudinary.com/infokost/image/upload/w_660,h_420/v1510559159/prod/property/2017/11/13/kost-tiong-paragon-exclusive-casablanca-setiabudi-jakarta-selatan_1510559154_820.jpg",
                                                                                "https://res.cloudinary.com/infokost/image/upload/w_660,h_420/v1510559165/prod/property/2017/11/13/kost-tiong-paragon-exclusive-casablanca-setiabudi-jakarta-selatan_1510559160_814.jpg",
                                                                                "https://res.cloudinary.com/infokost/image/upload/w_660,h_420/v1510559170/prod/property/2017/11/13/kost-tiong-paragon-exclusive-casablanca-setiabudi-jakarta-selatan_1510559166_431.jpg",
                                                                                "https://res.cloudinary.com/infokost/image/upload/w_660,h_420/v1510559176/prod/property/2017/11/13/kost-tiong-paragon-exclusive-casablanca-setiabudi-jakarta-selatan_1510559171_349.jpg",
                                                                                "https://res.cloudinary.com/infokost/image/upload/w_660,h_420/v1510559182/prod/property/2017/11/13/kost-tiong-paragon-exclusive-casablanca-setiabudi-jakarta-selatan_1510559177_466.jpg",
                                                                                "https://res.cloudinary.com/infokost/image/upload/w_660,h_420/v1510559188/prod/property/2017/11/13/kost-tiong-paragon-exclusive-casablanca-setiabudi-jakarta-selatan_1510559183_558.jpg",
                                                                                "https://res.cloudinary.com/infokost/image/upload/w_660,h_420/v1510559203/prod/property/2017/11/13/kost-tiong-paragon-exclusive-casablanca-setiabudi-jakarta-selatan_1510559198_709.jpg"
                                                ],
            "aggregateRating": {
                "@type": "AggregateRating",
                "ratingValue": "5",
                "reviewCount": "89",
                "bestRating": "5",
                "worstRating": "0"
            },
            "offers": {
                "@type": "AggregateOffer",
                "lowPrice": "4400000",
                "highPrice": "6000000",
                "priceCurrency": "IDR"
            }
        }
    </script>
</head>
<body>

<noscript><iframe title="google" src="https://www.googletagmanager.com/ns.html?id=GTM-55BRPMX"
                      height="0" width="0" style="display:none;visibility:hidden"></iframe></noscript>

<div id="app">
<input type="hidden" id="host" value="https://www.infokost.id" />
<input type="hidden" id="segment" value="detail" />
<input type="hidden" id="is_login_firebase" value="" />
<div class="app-wrap">
<div class="wrap-load d-none">
<div class="icon-load">
<em class="fas fa-spinner fa-spin font-40 text-white"></em>
</div>
</div>
<div class="header">
<div class="container">
<div class="row gutter-0">
<div class="col-md-2 mt-3 mb-3 font-14">
<a href="https://play.google.com/store/apps/details?id=net.infokost.infokostapp" target="_blank">Download Infokost App</a>
</div>
<div id="navbar" class="col-md-10 text-right mt-3 mb-3 font-14">
<a class="" href="https://www.infokost.id/search?type=kost" data-value="kost">Kost</a>
<a class="margin-l-20 " href="https://www.infokost.id/search?type=apartemen" data-value="apartemen">Apartemen</a>
<a class="margin-l-20 " href="https://www.infokost.id/search?type=villa" data-value="villa">Villa</a>
<a class="margin-l-20 " href="https://www.infokost.id/search?type=hunian" data-value="hunian">Hunian lain</a>
<a class="margin-l-20 position-relative" href="https://campaign.infokost.id/owner">Promosikan Hunian Anda <div style="right: -5px; top: -15px" class="badge badge-danger position-absolute">GRATIS</div></a>
<a class="margin-l-20 " href="https://www.infokost.id/check_order">Cek Pesanan</a>
</div>
<div class="col-md-2">
<a href="https://www.infokost.id">
<div class="logo"><img src="https://www.infokost.id/images/infokost.png" width="138" alt="infokost" /></div>
</a>
</div>
<div class="col-md-8">
<div class="search-top">
<form id="searching" class="form-inline w-100" action="https://www.infokost.id/search?area=" method="get">
<div class="col-md-11">
<input type="text" id="area" name="q" class="form-control input-search-top" placeholder="Cari area" value="">
</div>
<div id="auto autocomplete"></div>
<div class="col-md-1">
<button class="btn btn-searchtop" type="submit" id="search"><em class="fa fa-search"></em></button>
</div>
</form>
</div>
</div>
<div class="col-md-2 text-right">
<a class="margin-l-20 d-inline-block mt-2" href="https://www.infokost.id/login">Masuk</a>
<a class="margin-l-20 d-inline-block mt-2" href="https://www.infokost.id/register">Daftar</a>
</div>
<div class="col-md-10 offset-md-2 filter-area">
</div>
</div>
</div>
</div>
<main role="main" class="main">
<div class="container">
<nav aria-label="breadcrumb">
<ol class="breadcrumb">
<li class="breadcrumb-item"><a href="https://www.infokost.id">Beranda</a></li>
<li class="breadcrumb-item"><a href="https://www.infokost.id/search">Pencarian</a></li>
<li class="breadcrumb-item active" aria-current="page">Detail</li>
</ol>
</nav>
<div class="row">
<div class="col-md-12">
<div class="col-left-detail">
<div class="row">
<div class="col-md-12 title-detail">
<div class="badge-wrap">
<div class="badge-like-detail Berlangganan">
<em class="fas fa-gem like Berlangganan font-20"></em>
</div>
</div>
<h2 class="featurette-heading m-0 font-25">Kost Tiong Paragon Exclusive Casablanca</h2>
<small>
Jabodetabek, Jakarta Selatan, Setiabudi, Karet Kuningan,
</small>
</div>
</div>
<div class="row gutter-0">
<div class="col-md-12">
<div class="photos">
<div class="image1"><img src="https://res.cloudinary.com/infokost/image/upload/w_660,h_420/v1510559129/prod/property/2017/11/13/kost-tiong-paragon-exclusive-casablanca-setiabudi-jakarta-selatan_1510559124_236.jpg" width="560" height="320" alt="Kost Tiong Paragon Exclusive Casablanca" /></div>
<div class="image2"><img src="https://res.cloudinary.com/infokost/image/upload/w_660,h_420/v1510559135/prod/property/2017/11/13/kost-tiong-paragon-exclusive-casablanca-setiabudi-jakarta-selatan_1510559130_803.jpg" width="220" height="155" alt="Kost Tiong Paragon Exclusive Casablanca" /></div>
<div class="image3">
<div class="more-photos more-images offset">
<ul>
<li class="d-none" data-mfp-src="https://res.cloudinary.com/infokost/image/upload/w_660,h_420/v1510559129/prod/property/2017/11/13/kost-tiong-paragon-exclusive-casablanca-setiabudi-jakarta-selatan_1510559124_236.jpg"></li>
<li class="d-none" data-mfp-src="https://res.cloudinary.com/infokost/image/upload/w_660,h_420/v1510559135/prod/property/2017/11/13/kost-tiong-paragon-exclusive-casablanca-setiabudi-jakarta-selatan_1510559130_803.jpg"></li>
<li class="d-none" data-mfp-src="https://res.cloudinary.com/infokost/image/upload/w_660,h_420/v1510559141/prod/property/2017/11/13/kost-tiong-paragon-exclusive-casablanca-setiabudi-jakarta-selatan_1510559136_516.jpg"></li>
<li class="d-none" data-mfp-src="https://res.cloudinary.com/infokost/image/upload/w_660,h_420/v1510559147/prod/property/2017/11/13/kost-tiong-paragon-exclusive-casablanca-setiabudi-jakarta-selatan_1510559142_735.jpg"></li>
<li class="d-none" data-mfp-src="https://res.cloudinary.com/infokost/image/upload/w_660,h_420/v1510559153/prod/property/2017/11/13/kost-tiong-paragon-exclusive-casablanca-setiabudi-jakarta-selatan_1510559148_996.jpg"></li>
<li class="d-none" data-mfp-src="https://res.cloudinary.com/infokost/image/upload/w_660,h_420/v1510559159/prod/property/2017/11/13/kost-tiong-paragon-exclusive-casablanca-setiabudi-jakarta-selatan_1510559154_820.jpg"></li>
<li class="d-none" data-mfp-src="https://res.cloudinary.com/infokost/image/upload/w_660,h_420/v1510559165/prod/property/2017/11/13/kost-tiong-paragon-exclusive-casablanca-setiabudi-jakarta-selatan_1510559160_814.jpg"></li>
<li class="d-none" data-mfp-src="https://res.cloudinary.com/infokost/image/upload/w_660,h_420/v1510559170/prod/property/2017/11/13/kost-tiong-paragon-exclusive-casablanca-setiabudi-jakarta-selatan_1510559166_431.jpg"></li>
<li class="d-none" data-mfp-src="https://res.cloudinary.com/infokost/image/upload/w_660,h_420/v1510559176/prod/property/2017/11/13/kost-tiong-paragon-exclusive-casablanca-setiabudi-jakarta-selatan_1510559171_349.jpg"></li>
<li class="d-none" data-mfp-src="https://res.cloudinary.com/infokost/image/upload/w_660,h_420/v1510559182/prod/property/2017/11/13/kost-tiong-paragon-exclusive-casablanca-setiabudi-jakarta-selatan_1510559177_466.jpg"></li>
<li class="d-none" data-mfp-src="https://res.cloudinary.com/infokost/image/upload/w_660,h_420/v1510559188/prod/property/2017/11/13/kost-tiong-paragon-exclusive-casablanca-setiabudi-jakarta-selatan_1510559183_558.jpg"></li>
<li class="d-none" data-mfp-src="https://res.cloudinary.com/infokost/image/upload/w_660,h_420/v1510559203/prod/property/2017/11/13/kost-tiong-paragon-exclusive-casablanca-setiabudi-jakarta-selatan_1510559198_709.jpg"></li>
</ul>
<span>Lihat 12 Foto</span>
</div>
<img src="https://res.cloudinary.com/infokost/image/upload/w_660,h_420/v1510559141/prod/property/2017/11/13/kost-tiong-paragon-exclusive-casablanca-setiabudi-jakarta-selatan_1510559136_516.jpg" width="220" height="155" alt="Kost Tiong Paragon Exclusive Casablanca" />
</div>
</div>
</div>
</div>
<div class="row gutter-10">
<div class="col-md-12 mt-4">
<h2 class="lead">Penghuni</h2>
<div class="font-16">Wanita Pria</div>
<div class="font-16">Suami / Istri</div>
</div>
<div class="col-md-12 mt-4">
<h2 class="lead">Mayoritas Penghuni</h2>
<div class="font-16">Karyawan</div>
<div class="font-16">Karyawati</div>
<div class="font-16">Executive</div>
</div>
<div class="col-md-12 mt-4">
<h2 class="lead">Website</h2>
<div class="font-16"><a href="http://-" rel="nofollow" target="_blank">-</a></div>
</div>
<div class="col-md-12 mt-4">
<h2 class="lead">Fasilitas Hunian</h2>
<div class="row gutter-10 mt-3">
<div class="col-md-3 fac-icon">
<img src="https://www.infokost.id/images/svg/kamar-mandi-luar.svg" alt="kamar-mandi-luar" width="40" height="40">
<p>Kamar Mandi Luar</p>
</div>
<div class="col-md-3 fac-icon">
<img src="https://www.infokost.id/images/svg/dapur.svg" alt="dapur" width="40" height="40">
<p>Dapur</p>
</div>
<div class="col-md-3 fac-icon">
<img src="https://www.infokost.id/images/svg/pembantu.svg" alt="pembantu" width="40" height="40">
<p>Pembantu</p>
</div>
<div class="col-md-3 fac-icon">
<img src="https://www.infokost.id/images/svg/parkir-mobil.svg" alt="parkir-mobil" width="40" height="40">
<p>Parkir Mobil</p>
</div>
<div class="col-md-3 fac-icon">
<img src="https://www.infokost.id/images/svg/parkir-motor.svg" alt="parkir-motor" width="40" height="40">
<p>Parkir Motor</p>
</div>
<div class="col-md-3 fac-icon">
<img src="https://www.infokost.id/images/svg/tv.svg" alt="tv" width="40" height="40">
<p>Tv</p>
</div>
<div class="col-md-3 fac-icon">
<img src="https://www.infokost.id/images/svg/security-cctv.svg" alt="security-cctv" width="40" height="40">
<p>Security / Cctv</p>
</div>
<div class="col-md-3 fac-icon">
<img src="https://www.infokost.id/images/svg/kulkas.svg" alt="kulkas" width="40" height="40">
<p>Kulkas</p>
</div>
<div class="col-md-3 fac-icon">
<img src="https://www.infokost.id/images/svg/wifi.svg" alt="wifi" width="40" height="40">
<p>Wifi</p>
</div>
<div class="col-md-3 fac-icon">
<img src="https://www.infokost.id/images/svg/ruang-tamu.svg" alt="ruang-tamu" width="40" height="40">
<p>Ruang Tamu</p>
</div>
</div>
</div>
<div class="col-md-12 mt-4">
<h2 class="lead">Binatang Peliharan</h2>
<div class="font-16">Tidak Boleh</div>
</div>
<div class="col-md-12 mt-4">
<h2 class="lead">Fasilitas Sekitar</h2>
<div class="row gutter-10 mt-3">
<div class="col-md-3 fac-icon">
<img src="https://www.infokost.id/images/svg/tol.svg" alt="tol" width="40" height="40">
<p>Tol</p>
</div>
<div class="col-md-3 fac-icon">
<img src="https://www.infokost.id/images/svg/supermarket.svg" alt="supermarket" width="40" height="40">
<p>Supermarket</p>
</div>
<div class="col-md-3 fac-icon">
<img src="https://www.infokost.id/images/svg/rumah-sakit.svg" alt="rumah-sakit" width="40" height="40">
<p>Rumah Sakit</p>
</div>
<div class="col-md-3 fac-icon">
<img src="https://www.infokost.id/images/svg/rumah-makan.svg" alt="rumah-makan" width="40" height="40">
<p>Rumah Makan</p>
</div>
<div class="col-md-3 fac-icon">
<img src="https://www.infokost.id/images/svg/mall.svg" alt="mall" width="40" height="40">
<p>Mall</p>
</div>
<div class="col-md-3 fac-icon">
<img src="https://www.infokost.id/images/svg/kampus.svg" alt="kampus" width="40" height="40">
<p>Kampus</p>
</div>
<div class="col-md-3 fac-icon">
<img src="https://www.infokost.id/images/svg/halte-bus.svg" alt="halte-bus" width="40" height="40">
<p>Halte Bus</p>
</div>
</div>
</div>
<div class="col-md-12 mt-4">
<h2 class="lead">Keterangan Lain</h2>
<div class="font-16">
<p><p>Info biaya tambahan:<br />
- Biaya parkir mobil: 300.000 s/d 350.000,-/bln<br />
- Sewa kamar berdua terdapat tambahan biaya Rp. 500.000,- /bln<br />
- Terdapat save deposit Rp. 2.000.000,- dibayar pada saat buka kamar<br />
<br />
Fasilitas tambahan:<br />
- Free biaya listrik dan internet<br />
- Free cuci setrika baju maksimum 4 potong perhari<br />
- Tempat kost exclusive, aman &amp; nyaman<br />
<br />
Akses lokasi:<br />
- Tepat berada di area strategis kawasan perkantoran Jl. Sudirman, Jl. MH Thamrin, Jl. Dr Prof Satrio &amp; Jl HR Rasuna Said<br />
- Dekat dengan&nbsp;Mall Ambassador &amp; Plaza Semanggi<br />
- Dekat halte Busway / MRT Karet ( 12 menit )<br />
&nbsp;</p></p>
</div>
</div>
</div>
</div>
<div class="col-right-detail">
<div class="row margin-b-10">
<div class="col-md-12 text-right mb-4">
<div class="share-text">Bagikan :</div>
<a class="share-button" title="share facebook" href="https://www.facebook.com/sharer.php?u=https://www.infokost.id/detail/kost-tiong-paragon-exclusive-casablanca-setiabudi-jakarta-selatan" target="_blank">
 <div class="share-fb mr-2">
<em class="fab fa-facebook-f font-22" aria-hidden="true"></em>
</div>
</a>
<a class="share-button" title="share twitter" href="https://twitter.com/intent/tweet?url=https://www.infokost.id/detail/kost-tiong-paragon-exclusive-casablanca-setiabudi-jakarta-selatan" target="_blank">
<div class="share-tw mr-2">
<em class="fab fa-twitter font-22" aria-hidden="true"></em>
</div>
</a>
<div class="share-link">
<span class="tooltiptext" title="copy link" id="myTooltip"></span>
<em class="fas fa-link font-22" aria-hidden="true"></em>
<input id="link-copy" class="link-copy" type="text" value="https://www.infokost.id/detail/kost-tiong-paragon-exclusive-casablanca-setiabudi-jakarta-selatan" readonly>
</div>
</div>
</div>
<div class="row gutter-0">
<div class="col-md-12 bg-light-tomato p-2 mb-3">
<div class="lead mb-1">Verifikasi</div>
<div class="font-18">
<em class="far fa-check-circle text-success"></em> Data terverifikasi
</div>
<div class="font-18">
<em class="far fa-check-circle text-success"></em> Sudah dikunjungi
</div>
</div>
</div>
<div class="card rounded-0">
<div class="card-header lead">
Informasi
</div>
<div class="card-body">
<a target="blank" href="https://message.infokost.id/?slug=kost-tiong-paragon-exclusive-casablanca-setiabudi-jakarta-selatan" class="btn btn-orange bookmark w-100">Tanya Kamar</a>
<p class="text-center mt-2 mb-0"><small>Terakhir di update 2020-02-24 15:12:22</small></p>
</div>
</div>
<div class="row gutter-0">
<div class="col-md-12 mt-4">
<button data-content="inactive" datasrc="https://www.infokost.id/detail/kost-tiong-paragon-exclusive-casablanca-setiabudi-jakarta-selatan" id="24729575464393068" rel="" class="btn btn-outline-grey w-100 bookmark-love"><em id="bookmark-icon" class="far fa-heart font-20 pt-1"></em> Simpan</button>
</div>
</div>
<div class="row gutter-0">
<div class="col-md-12 mt-4">
<div class="lead">Alamat</div>
<div class="font-16">Jl Prof Dr Satrio Gg Tiong No 1 Jakarta Selatan</div>
<div class="show-maps" data-value="kost-tiong-paragon-exclusive-casablanca-setiabudi-jakarta-selatan">
<img class="cursor" src="https://www.infokost.id/images/maps_default.jpg" alt="Lihat Lokasi" width="300" height="150" />
<div class="btn-maps cursor">Lihat Lokasi</div>
</div>
</div>
</div>
</div>
</div>
</div>
<h3 class="text-left lead"><span>Info Kamar</span></h3>
<div class="col-md-12 border mt-3">
<span class="drop-room d-inline-block lead color-primary cursor mt-2 mb-2">
Deluxe ( Standard Single )
<em class="fa fa-angle-down font-16"></em>
</span>
</div>
<div class="mb-4">
<div class="d-table border border-top-0 w-100">
<div class="d-table-cell pb-3 pt-3 w-25">
<div class="col-md-11 m-0-auto cursor more-images p-0 d-block">
<div class="more-image-room">
<span><em class="far fa-image font-16"></em> 2 +</span>
</div>
<img src="https://res.cloudinary.com/infokost/image/upload/w_660,h_420/v1486958036/prod/room/2017/02/13/kost-tiong-paragon-exclusive-casablanca-setiabudi-jakarta-selatan_1486958031364_66.jpg" class="w-100 h-100" alt="deluxe-15661476841960324507" />
<div class="more-photos-room text-light d-none">
<ul>
<li class="d-none" data-mfp-src="https://res.cloudinary.com/infokost/image/upload/w_660,h_420/v1486958036/prod/room/2017/02/13/kost-tiong-paragon-exclusive-casablanca-setiabudi-jakarta-selatan_1486958031364_66.jpg"></li>
<li class="d-none" data-mfp-src="https://res.cloudinary.com/infokost/image/upload/w_660,h_420/v1486958052/prod/room/2017/02/13/kost-tiong-paragon-exclusive-casablanca-setiabudi-jakarta-selatan_1486958045849_33.jpg"></li>
</ul>
</div>
</div>
</div>
<div class="d-table-cell border-left align-top p-0 w-20">
<div class="col-md-12 border-bottom text-center mb-3">
<p class="mt-2 mb-2 font-16 text-left">Info Kamar</p>
</div>
<div class="padding-lr-15">
<span>
<img src="https://www.infokost.id/images/svg/tamu.svg" width="25" height="25" alt="svg-jumlah-tamu">
Maksimal 2 Orang
</span>
</div>
<div class="padding-lr-15 mt-2">
<span>
<img src="https://www.infokost.id/images/svg/luas-kamar.svg" width="28" height="28" alt="svg-luas-kamar">
Ukuran 5x7m2
</span>
</div>
<div class="col-md-12 text-left mt-2 mb-2">
<img src="https://www.infokost.id/images/svg/ruang-tamu.svg" width="28" height="28" alt="svg-facility">
<span class="room-more-btn cursor d-inline-block align-bottom" data-value="facility">
Fasilitas 0
+ <em class="fa fa-angle-up" aria-hidden="true"></em>
</span>
</div>
</div>
<div class="d-table-cell border-left align-top p-0 w-25">
<div class="col-md-12 border-bottom text-center mb-3">
<p class="mt-2 mb-2 text-left font-16">Deskripsi dan Aturan</p>
</div>
<div class="padding-lr-15 mt-2">
<span class="room-more-btn cursor" data-value="cancel">
<img src="https://www.infokost.id/images/svg/rak-buku.svg" width="25" height="25" alt="svg-room-cancel">
Pembatalan Kamar <em class="fa fa-angle-up" aria-hidden="true"></em>
</span>
</span>
</div>
<div class="padding-lr-15">
<div class="col-md-12 p-0 text-left mt-2 mb-2">
<span class="room-more-btn cursor" data-value="desc">
<img src="https://www.infokost.id/images/svg/rak-buku.svg" width="25" height="25" alt="svg-room-desc">
Deskripsi Kamar <em class="fa fa-angle-up" aria-hidden="true"></em>
</span>
</span>
</div>
</div>
<div class="padding-lr-15">
<div class="col-md-12 p-0 text-left mt-2 mb-2">
<span class="room-more-btn cursor" data-value="rule">
<img src="https://www.infokost.id/images/svg/rak-buku.svg" width="25" height="25" alt="svg-room-rule">
Aturan Kamar <em class="fa fa-angle-up" aria-hidden="true"></em>
</span>
</span>
</div>
</div>
</div>
<div class="d-table-cell border-left align-top p-0 w-30">
<div class="col-md-12 border-bottom mb-3 text-center">
<p class="mt-2 mb-2 text-left font-16">Harga</p>
</div>
<div class="col-md-12 d-inline-block">
<form class="form-date" method="get" action="https://www.infokost.id/booking/order_date">
<div class="col-md-8 p-0 float-left">
<div class="form-check">
<input id="room-monthly-0" class="form-check-input" type="radio" name="price" value="monthly" checked>
<label for="room-monthly-0">
<span class="form-check-label color-price m-0 d-inline-block font-16">Rp 4.400.000</span> /bulan
</label>
</div>
</div>
<div class="col-md-4 p-0 float-right text-right d-inline-block">
<input type="hidden" name="slug" value="deluxe-15661476841960324507">
<input class="d-inline-block btn btn-primary" type="submit" value="Pesan">
</div>
</form>
</div>
</div>
</div>
<div class="room-more col-md-12 border border-top-0 pt-2 pb-2 mb-4" data-value="facility" style="display: none">
<div class="d-inline-block w-100">
<h3>Fasilitas</h3>
</div>
</div>
<div class="room-more col-md-12 border border-top-0 pt-2 pb-2 mb-4" data-value="cancel" style="display: none">
<h3>Pembatalan Kamar</h3>
-
</div>
<div class="room-more col-md-12 border border-top-0 pt-2 pb-2 mb-4" data-value="desc" style="display: none">
<h3>Deskripsi Kamar</h3>
-
</div>
<div class="room-more col-md-12 border border-top-0 pt-2 pb-2 mb-4" data-value="rule" style="display: none">
<h3>Aturan Kamar</h3>
-
</div>
</div>
<div class="col-md-12 border mt-3">
<span class="drop-room d-inline-block lead color-primary cursor mt-2 mb-2">
Executive ( Standard Single )
<em class="fa fa-angle-down font-16"></em>
</span>
</div>
<div class="mb-4">
<div class="d-table border border-top-0 w-100">
<div class="d-table-cell pb-3 pt-3 w-25">
<div class="col-md-11 m-0-auto cursor more-images p-0 d-block">
<div class="more-image-room">
<span><em class="far fa-image font-16"></em> 6 +</span>
</div>
<img src="https://res.cloudinary.com/infokost/image/upload/w_660,h_420/v1479893250/prod/room/2016/11/23/kost-tiong-paragon-exclusive-casablanca-setiabudi-jakarta-selatan_1479893248127_42.jpg" class="w-100 h-100" alt="executive-1566147678242319577" />
<div class="more-photos-room text-light d-none">
<ul>
<li class="d-none" data-mfp-src="https://res.cloudinary.com/infokost/image/upload/w_660,h_420/v1479893250/prod/room/2016/11/23/kost-tiong-paragon-exclusive-casablanca-setiabudi-jakarta-selatan_1479893248127_42.jpg"></li>
<li class="d-none" data-mfp-src="https://res.cloudinary.com/infokost/image/upload/w_660,h_420/v1479893257/prod/room/2016/11/23/kost-tiong-paragon-exclusive-casablanca-setiabudi-jakarta-selatan_1479893257819_22.jpg"></li>
<li class="d-none" data-mfp-src="https://res.cloudinary.com/infokost/image/upload/w_660,h_420/v1479893265/prod/room/2016/11/23/kost-tiong-paragon-exclusive-casablanca-setiabudi-jakarta-selatan_1479893265766_16.jpg"></li>
<li class="d-none" data-mfp-src="https://res.cloudinary.com/infokost/image/upload/w_660,h_420/v1479893274/prod/room/2016/11/23/kost-tiong-paragon-exclusive-casablanca-setiabudi-jakarta-selatan_1479893274705_71.jpg"></li>
<li class="d-none" data-mfp-src="https://res.cloudinary.com/infokost/image/upload/w_660,h_420/v1479893281/prod/room/2016/11/23/kost-tiong-paragon-exclusive-casablanca-setiabudi-jakarta-selatan_1479893281689_80.jpg"></li>
<li class="d-none" data-mfp-src="https://res.cloudinary.com/infokost/image/upload/w_660,h_420/v1479893288/prod/room/2016/11/23/kost-tiong-paragon-exclusive-casablanca-setiabudi-jakarta-selatan_1479893287895_104.jpg"></li>
</ul>
</div>
</div>
</div>
<div class="d-table-cell border-left align-top p-0 w-20">
<div class="col-md-12 border-bottom text-center mb-3">
<p class="mt-2 mb-2 font-16 text-left">Info Kamar</p>
</div>
<div class="padding-lr-15">
<span>
<img src="https://www.infokost.id/images/svg/tamu.svg" width="25" height="25" alt="svg-jumlah-tamu">
Maksimal 2 Orang
</span>
</div>
<div class="padding-lr-15 mt-2">
<span>
<img src="https://www.infokost.id/images/svg/luas-kamar.svg" width="28" height="28" alt="svg-luas-kamar">
Ukuran 5x7m2 s/d 7x7m2
</span>
</div>
<div class="col-md-12 text-left mt-2 mb-2">
<img src="https://www.infokost.id/images/svg/ruang-tamu.svg" width="28" height="28" alt="svg-facility">
<span class="room-more-btn cursor d-inline-block align-bottom" data-value="facility">
Fasilitas 0
+ <em class="fa fa-angle-up" aria-hidden="true"></em>
</span>
</div>
</div>
<div class="d-table-cell border-left align-top p-0 w-25">
<div class="col-md-12 border-bottom text-center mb-3">
<p class="mt-2 mb-2 text-left font-16">Deskripsi dan Aturan</p>
</div>
<div class="padding-lr-15 mt-2">
<span class="room-more-btn cursor" data-value="cancel">
<img src="https://www.infokost.id/images/svg/rak-buku.svg" width="25" height="25" alt="svg-room-cancel">
Pembatalan Kamar <em class="fa fa-angle-up" aria-hidden="true"></em>
</span>
</span>
</div>
<div class="padding-lr-15">
<div class="col-md-12 p-0 text-left mt-2 mb-2">
<span class="room-more-btn cursor" data-value="desc">
<img src="https://www.infokost.id/images/svg/rak-buku.svg" width="25" height="25" alt="svg-room-desc">
Deskripsi Kamar <em class="fa fa-angle-up" aria-hidden="true"></em>
</span>
</span>
</div>
</div>
<div class="padding-lr-15">
<div class="col-md-12 p-0 text-left mt-2 mb-2">
<span class="room-more-btn cursor" data-value="rule">
<img src="https://www.infokost.id/images/svg/rak-buku.svg" width="25" height="25" alt="svg-room-rule">
Aturan Kamar <em class="fa fa-angle-up" aria-hidden="true"></em>
</span>
</span>
</div>
</div>
</div>
<div class="d-table-cell border-left align-top p-0 w-30">
<div class="col-md-12 border-bottom mb-3 text-center">
<p class="mt-2 mb-2 text-left font-16">Harga</p>
</div>
<div class="col-md-12 d-inline-block">
<form class="form-date" method="get" action="https://www.infokost.id/booking/order_date">
<div class="col-md-8 p-0 float-left">
<div class="form-check">
<input id="room-monthly-1" class="form-check-input" type="radio" name="price" value="monthly" checked>
<label for="room-monthly-1">
<span class="form-check-label color-price m-0 d-inline-block font-16">Rp 6.000.000</span> /bulan
</label>
</div>
</div>
<div class="col-md-4 p-0 float-right text-right d-inline-block">
<input type="hidden" name="slug" value="executive-1566147678242319577">
<input class="d-inline-block btn btn-primary" type="submit" value="Pesan">
</div>
</form>
</div>
</div>
</div>
<div class="room-more col-md-12 border border-top-0 pt-2 pb-2 mb-4" data-value="facility" style="display: none">
<div class="d-inline-block w-100">
<h3>Fasilitas</h3>
</div>
</div>
<div class="room-more col-md-12 border border-top-0 pt-2 pb-2 mb-4" data-value="cancel" style="display: none">
<h3>Pembatalan Kamar</h3>
-
</div>
<div class="room-more col-md-12 border border-top-0 pt-2 pb-2 mb-4" data-value="desc" style="display: none">
<h3>Deskripsi Kamar</h3>
-
</div>
<div class="room-more col-md-12 border border-top-0 pt-2 pb-2 mb-4" data-value="rule" style="display: none">
<h3>Aturan Kamar</h3>
-
</div>
</div>
<hr class="featurette-divider-2">
<div class="row hunian-lain">
<div class="col-md-12 mb-1"><em class="fas fa-home"></em> HUNIAN LAIN</div>
</div>
<div class="margin-lr-min5">
<div class="detail-carousel">
<div class="carousel-cell col-md-3 padding-lr-5">
<div class="badge-search-wrap">
<div class="badge-search Berlangganan">
<em class="fas fa-gem like Berlangganan font-16"></em>
</div>
</div>
<div class="property-img">
<a href="https://www.infokost.id/detail/kost-sastrodikoro-residence-di-scbd-kebayoran-baru-jakarta-selatan" title="TR - Esidence">
<img class="lazy img-fluid" src="https://res.cloudinary.com/infokost/image/upload/c_thumb,w_277,h_173/v1510561138/prod/property/2017/11/13/kost-sastrodikoro-residence-di-scbd-kebayoran-baru-jakarta-selatan_1510561134_676.jpg" alt="Kost Bintang Residence">
</a>
</div>
<div class="property-content">
<div class="property-title">
<a href="https://www.infokost.id/detail/kost-sastrodikoro-residence-di-scbd-kebayoran-baru-jakarta-selatan" title="Kost Bintang Residence">
<h1>Kost Sastrodikoro Residence</h1>
</a>
</div>
<div class="property-address">
<h2>Jl. Tulodong Atas No. 14 Senayan Kebayoran Baru Jakarta Selatan</h2>
</div>
<div class="property-price">
<h3>Lihat Detail <span></span></h3>
</div>
</div>
</div>
<div class="carousel-cell col-md-3 padding-lr-5">
<div class="badge-search-wrap">
<div class="badge-search Berlangganan">
<em class="fas fa-gem like Berlangganan font-16"></em>
</div>
</div>
<div class="property-img">
<a href="https://www.infokost.id/detail/kost-jl-kalibata-tengah-no-2-pancoran-jakarta-selatan" title="TR - Esidence">
<img class="lazy img-fluid" src="https://res.cloudinary.com/infokost/image/upload/c_thumb,w_277,h_173/v1511753772/prod/property/2017/11/27/kost-jl-kalibata-tengah-no-2-pancoran-jakarta-selatan_1511753768_975.jpg" alt="Kost Bintang Residence">
</a>
</div>
<div class="property-content">
<div class="property-title">
<a href="https://www.infokost.id/detail/kost-jl-kalibata-tengah-no-2-pancoran-jakarta-selatan" title="Kost Bintang Residence">
<h1>Kost H Rohili</h1>
</a>
</div>
<div class="property-address">
<h2>Jl. Kalibata Tengah Gg. Pepaya No. 2 Rt. 04 Rw. 03 Kalibata Jakarta Selatan</h2>
</div>
<div class="property-price">
<h3>Lihat Detail <span></span></h3>
</div>
</div>
</div>
<div class="carousel-cell col-md-3 padding-lr-5">
<div class="badge-search-wrap">
<div class="badge-search Berlangganan">
<em class="fas fa-gem like Berlangganan font-16"></em>
</div>
</div>
<div class="property-img">
<a href="https://www.infokost.id/detail/kost-tiong-paragon-exclusive-casablanca-setiabudi-jakarta-selatan" title="TR - Esidence">
<img class="lazy img-fluid" src="https://res.cloudinary.com/infokost/image/upload/c_thumb,w_277,h_173/v1510559129/prod/property/2017/11/13/kost-tiong-paragon-exclusive-casablanca-setiabudi-jakarta-selatan_1510559124_236.jpg" alt="Kost Bintang Residence">
</a>
</div>
<div class="property-content">
<div class="property-title">
<a href="https://www.infokost.id/detail/kost-tiong-paragon-exclusive-casablanca-setiabudi-jakarta-selatan" title="Kost Bintang Residence">
<h1>Kost Tiong Paragon Exclusive Casablanca</h1>
</a>
</div>
<div class="property-address">
<h2>Jl Prof Dr Satrio Gg Tiong No 1 Jakarta Selatan</h2>
</div>
<div class="property-price">
<h3>Lihat Detail <span></span></h3>
</div>
</div>
</div>
<div class="carousel-cell col-md-3 padding-lr-5">
<div class="badge-search-wrap">
<div class="badge-search Berlangganan">
<em class="fas fa-gem like Berlangganan font-16"></em>
</div>
</div>
<div class="property-img">
<a href="https://www.infokost.id/detail/kost-innova-home" title="TR - Esidence">
<img class="lazy img-fluid" src="https://res.cloudinary.com/infokost/image/upload/c_thumb,w_277,h_173/v1518427544/prod/property/2018/02/12/kost-innova-home_1518427538_623.jpg" alt="Kost Bintang Residence">
</a>
</div>
<div class="property-content">
<div class="property-title">
<a href="https://www.infokost.id/detail/kost-innova-home" title="Kost Bintang Residence">
<h1>Kost Innova Home</h1>
</a>
</div>
<div class="property-address">
<h2>Jl. Kelapa Lilin Utara 2 Blok DF 4 No. 7 Sektor 7c Gading Serpong Tangerang</h2>
</div>
<div class="property-price">
<h3>Lihat Detail <span></span></h3>
</div>
</div>
</div>
<div class="carousel-cell col-md-3 padding-lr-5">
<div class="badge-search-wrap">
 <div class="badge-search Berlangganan">
<em class="fas fa-gem like Berlangganan font-16"></em>
</div>
</div>
<div class="property-img">
<a href="https://www.infokost.id/detail/koolkost-near-universitas-negeri-makassar" title="TR - Esidence">
<img class="lazy img-fluid" src="https://res.cloudinary.com/infokost/image/upload/c_thumb,w_277,h_173/b_black,c_mpad,h_75,w_100/v1581997544/prod/images/infokost/property/2020/02/18/1581997537_83.jpg" alt="Kost Bintang Residence">
</a>
</div>
<div class="property-content">
<div class="property-title">
<a href="https://www.infokost.id/detail/koolkost-near-universitas-negeri-makassar" title="Kost Bintang Residence">
<h1>KoolKost Near Universitas Negeri Makassar</h1>
</a>
</div>
<div class="property-address">
<h2>Jl. Skarda N1 No. 26D Gunung Sari Rappocini Makassar</h2>
</div>
<div class="property-price">
<h3>Lihat Detail <span></span></h3>
</div>
</div>
</div>
<div class="carousel-cell col-md-3 padding-lr-5">
<div class="badge-search-wrap">
<div class="badge-search Berlangganan">
<em class="fas fa-gem like Berlangganan font-16"></em>
</div>
</div>
<div class="property-img">
<a href="https://www.infokost.id/detail/koolkost-near-upn-yogyakarta" title="TR - Esidence">
<img class="lazy img-fluid" src="https://res.cloudinary.com/infokost/image/upload/c_thumb,w_277,h_173/b_black,c_mpad,h_75,w_100/v1581998755/prod/images/infokost/property/2020/02/18/1581998748_85.jpg" alt="Kost Bintang Residence">
</a>
</div>
<div class="property-content">
<div class="property-title">
<a href="https://www.infokost.id/detail/koolkost-near-upn-yogyakarta" title="Kost Bintang Residence">
<h1>KoolKost Near UPN Yogyakarta</h1>
</a>
</div>
<div class="property-address">
<h2>Jl. Jangkar Bumi No. 377F Kledokan Caturtunggal Depok Sleman</h2>
</div>
<div class="property-price">
<h3>Lihat Detail <span></span></h3>
</div>
</div>
</div>
<div class="carousel-cell col-md-3 padding-lr-5">
<div class="badge-search-wrap">
<div class="badge-search Berlangganan">
<em class="fas fa-gem like Berlangganan font-16"></em>
</div>
</div>
<div class="property-img">
<a href="https://www.infokost.id/detail/koolkost-near-uii-jakal-yogyakarta" title="TR - Esidence">
<img class="lazy img-fluid" src="https://res.cloudinary.com/infokost/image/upload/c_thumb,w_277,h_173/b_black,c_mpad,h_75,w_100/v1579161427/prod/images/infokost/property/2020/01/16/1579161419_11.jpg" alt="Kost Bintang Residence">
</a>
</div>
<div class="property-content">
<div class="property-title">
<a href="https://www.infokost.id/detail/koolkost-near-uii-jakal-yogyakarta" title="Kost Bintang Residence">
<h1>KoolKost Near UII Jakal Yogyakarta</h1>
</a>
</div>
<div class="property-address">
<h2>Jl. Kaliurang KM. 15 Dusun Degolan Rt. 04 Rw. 03 Gang Srikandi Umbulmartani Ngemplak Sleman</h2>
</div>
<div class="property-price">
<h3>Lihat Detail <span></span></h3>
</div>
</div>
</div>
<div class="carousel-cell col-md-3 padding-lr-5">
<div class="badge-search-wrap">
<div class="badge-search Berlangganan">
<em class="fas fa-gem like Berlangganan font-16"></em>
</div>
</div>
<div class="property-img">
<a href="https://www.infokost.id/detail/koolkost-syariah-near-satelit-indah" title="TR - Esidence">
<img class="lazy img-fluid" src="https://res.cloudinary.com/infokost/image/upload/c_thumb,w_277,h_173/b_black,c_mpad,h_75,w_100/v1579161089/prod/images/infokost/property/2020/01/16/1579161082_98.jpg" alt="Kost Bintang Residence">
</a>
</div>
<div class="property-content">
<div class="property-title">
<a href="https://www.infokost.id/detail/koolkost-syariah-near-satelit-indah" title="Kost Bintang Residence">
<h1>KoolKost Syariah Near Satelit Indah</h1>
</a>
</div>
<div class="property-address">
<h2>Jl. Tanjungsari Baru VIII HH/29 Sukomanunggal Surabaya</h2>
</div>
<div class="property-price">
<h3>Lihat Detail <span></span></h3>
</div>
</div>
</div>
</div>
</div>
<hr class="featurette-divider-2">
<div class="modal modal-map fade" tabindex="-1" role="dialog" aria-labelledby="menu" aria-hidden="true" data-backdrop="false">
<div class="modal-dialog">
<div class="modal-content">
<div class="modal-header">
<div class="modal-title">Lokasi</div>
<div class="modal-close" data-dismiss="modal"><em class="far fa-times-circle"></em></div>
</div>
<div class="modal-body p-0">
<div class="modal-map-body w-100 h-100"></div>
</div>
</div>
</div>
</div>
</div>
</main>
<div class="footer">
<div class="container">
<div class="row">
<div class="col-md-3">
<h5>Perusahaan</h5>
<ul class="list-unstyled text-small">
<li><a href="https://www.infokost.id/pages/about-us">Tentang Kami</a></li>
<li><a href="https://www.infokost.id/pages/contact-us">Hubungi Kami</a></li>

<li><a href="https://www.mediapuradigitalindonesia.com/karir">Karir</a></li>
<li><a href="https://www.infokost.id/pages/terms-of-use">Ketentuan Pengguna</a></li>
<li><a href="https://www.infokost.id/pages/privacy-policy">Kebijakan Privasi</a></li>
<li><a href="https://www.infokost.id/pages/advertise-with-us">Beriklan</a></li>
</ul>
</div>
<div class="col-md-3">
<h5>Produk</h5>
<ul class="list-unstyled text-small">
<li><a href="https://www.infokost.id" target="_blank">Infokost.id</a></li>
<li><a href="http://www.1pintu.id" target="_blank">1pintu.id</a></li>
</ul>
</div>
<div class="col-md-3">
<h5>Layanan Pelanggan</h5>
<ul class="list-unstyled text-small">
<li><a href="tel:02129675858" target="_blank" class="text-muted">
<em class="fas font-20 color-phone fa-phone-square fa-flip-horizontal"></em> 021 2967 5858</a>
</li>
<li><a href="https://api.whatsapp.com/send?phone=628115875678&text=Halo,%20infokost.%20Saya%20ingin%20bertanya.." target="_blank" class="text-muted">
<em class="fab font-20 color-wa fa-whatsapp-square"></em> 0811 587 5678</a>
</li>
<li><a href="/cdn-cgi/l/email-protection#79181d1410173910171f1612160a0d57101d" class="text-muted">
<em class="fas font-20 color-email fa-envelope-square"></em> <span class="__cf_email__" data-cfemail="97f6f3fafef9d7fef9f1f8fcf8e4e3b9fef3">[email&#160;protected]</span></a>
</li>
</ul>
</div>
<div class="col-md-3">
<h5>Download Aplikasi</h5>
<ul class="list-unstyled text-small">
<li>
<a href="https://play.google.com/store/apps/details?id=net.infokost.infokostapp" target="_blank">
<img src="https://www.infokost.id/images/gplay.png" alt="Google Play" width="140" height="46" />
</a>
</li>
<li class="margin-t-10">
<a href="https://itunes.apple.com/us/app/infokost/id1369895552?ls=1&mt=8" target="_blank">
<img src="https://www.infokost.id/images/appstore.png" alt="App Store" width="140" height="47" />
</a>
</li>
</ul>
</div>
</div>
<div class="mt-4 mb-4">
<div class="row">
<div class="col-md-7 mt-2">
<p>&copy; PT. Mediapura Digital Indonesia. All right reserved 2007 - 2020</p>
</div>
<div class="col-md-5 text-right">
<a href="https://iqhs.app.link/x7L1BYfHzH" title="facebook infokost" target="_blank">
<em class="fab fa-facebook-square h2 color-fb mr-2"></em>
</a>
<a href="https://iqhs.app.link/FNGuY2xHzH" title="twitter infokost" target="_blank">
<em class="fab fa-twitter-square h2 color-tw mr-2"></em>
</a>
<a href="https://iqhs.app.link/5rB6mI2HzH" title="instagram infokost" target="_blank">
<em class="fab fa-instagram h2 color-insta"></em>
</a>
</div>
</div>
</div>
</div>
</div>
</div>
</div>
<script data-cfasync="false" src="/cdn-cgi/scripts/5c5dd728/cloudflare-static/email-decode.min.js"></script><script src="https://www.infokost.id/js/jquery-3.2.1.min.js"></script>
<script src="https://www.infokost.id/js/popper.min.js"></script>
<script src="https://www.infokost.id/js/bootstrap.min.js"></script>
<script src="https://www.infokost.id/js/jquery.magnific-popup.min.js"></script>
<script src="https://www.infokost.id/js/font-awesome.js"></script>
<script src="https://www.infokost.id/js/flickity.pkgd.js"></script>
<script src="https://www.infokost.id/js/jquery-ui.js"></script>
<script src="https://www.infokost.id/js/jquery.mousewheel.js"></script>
<script src="https://www.infokost.id/js/jquery.jscrollpane.min.js"></script>
<script src="https://www.infokost.id/js/main.js"></script>
<script src="https://www.infokost.id/js/login.js"></script>
<script src="https://www.infokost.id/js/jquery.validate.js"></script>
<script src="https://www.infokost.id/js/datepicker/picker.js"></script>
<script src="https://www.infokost.id/js/datepicker/picker.date.js"></script>
<script src="https://www.infokost.id/js/sweetalert.js"></script>

<script src="https://www.gstatic.com/firebasejs/6.3.4/firebase-app.js"></script>

<script src="https://www.gstatic.com/firebasejs/5.10.1/firebase-auth.js"></script>
<script src="https://www.gstatic.com/firebasejs/5.10.1/firebase-database.js"></script>
</body>
</html>
"""

# %%
import re

soup = BeautifulSoup(html_str)
montly_div = soup.select("label[for*=room-monthly-]")
#montly_div = soup.find_all("label", {"for": "room-monthly-0"})
for div in montly_div:
    print("".join(re.findall(r'\d+', div.text)))
# Out:
# 4400000
# 6000000

# %%
print(str(soup))
# Out:
# <html><body><div class="d-table border border-top-0 w-100">
# <div class="d-table-cell pb-3 pt-3 w-25">
# <div class="col-md-11 m-0-auto cursor more-images p-0 d-block">
# <div class="more-image-room">
# <span><svg aria-hidden="true" class="svg-inline--fa fa-image fa-w-16 font-16" data-fa-i2svg="" data-icon="image" data-prefix="far" role="img" viewbox="0 0 512 512" xmlns="http://www.w3.org/2000/svg"><path d="M464 64H48C21.49 64 0 85.49 0 112v288c0 26.51 21.49 48 48 48h416c26.51 0 48-21.49 48-48V112c0-26.51-21.49-48-48-48zm-6 336H54a6 6 0 0 1-6-6V118a6 6 0 0 1 6-6h404a6 6 0 0 1 6 6v276a6 6 0 0 1-6 6zM128 152c-22.091 0-40 17.909-40 40s17.909 40 40 40 40-17.909 40-40-17.909-40-40-40zM96 352h320v-80l-87.515-87.515c-4.686-4.686-12.284-4.686-16.971 0L192 304l-39.515-39.515c-4.686-4.686-12.284-4.686-16.971 0L96 304v48z" fill="currentColor"></path></svg><!-- <em class="far fa-image font-16"></em> --> 5 +</span>
# </div>
# ...
